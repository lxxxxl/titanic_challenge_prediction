# %% [markdown]
# # Data preparation

# %% [markdown]
# Import data and remove unused columns

# %%
import pandas as pd
import numpy as np

data_train = pd.read_csv('train.csv', index_col='PassengerId')
data_test = pd.read_csv('test.csv', index_col='PassengerId')

y_train = data_train['Survived']
# drop Name and Ticket columns because they are very noisy
X_train = data_train.drop(['Survived', 'Name', 'Ticket', 'Cabin', 'Embarked'], axis=1)
X_test = data_test.drop(['Name', 'Ticket', 'Cabin', 'Embarked'], axis=1)

# %% [markdown]
# Normalize data

# %%
X_train.describe()
# Out:
#            Pclass         Age       SibSp       Parch        Fare
# count  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.836071   14.526497    1.102743    0.806057   49.693429
# min      1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      3.000000   38.000000    1.000000    0.000000   31.000000
# max      3.000000   80.000000    8.000000    6.000000  512.329200

# %%
def normalize_data(data, mean, std):
  return (data - mean) / std

# %%
X_train['Age'] = X_train['Age'].fillna(X_train['Age'].mean())
X_test['Age'] = X_test['Age'].fillna(X_test['Age'].mean())

X_train['Age'] = normalize_data(X_train['Age'], X_train['Age'].mean(), X_train['Age'].std())
X_train['Fare'] = normalize_data(X_train['Fare'], X_train['Fare'].mean(), X_train['Fare'].std())
X_train['SibSp'] = normalize_data(X_train['SibSp'], X_train['SibSp'].mean(), X_train['SibSp'].std())
X_train['Parch'] = normalize_data(X_train['Parch'], X_train['Parch'].mean(), X_train['Parch'].std())
X_train['Pclass'] = normalize_data(X_train['Pclass'], X_train['Pclass'].mean(), X_train['Pclass'].std())

X_test['Age'] = normalize_data(X_test['Age'], X_test['Age'].mean(), X_test['Age'].std())
X_test['Fare'] = normalize_data(X_test['Fare'], X_test['Fare'].mean(), X_test['Fare'].std())
X_test['SibSp'] = normalize_data(X_test['SibSp'], X_test['SibSp'].mean(), X_test['SibSp'].std())
X_test['Parch'] = normalize_data(X_test['Parch'], X_test['Parch'].mean(), X_test['Parch'].std())
X_test['Pclass'] = normalize_data(X_test['Pclass'], X_test['Pclass'].mean(), X_test['Pclass'].std())

# %% [markdown]
# Process categorical data

# %%
X_train['Sex'] = pd.Categorical(X_train['Sex'])
X_train['Sex'] = X_train.Sex.cat.codes
X_test['Sex'] =  pd.Categorical(X_test['Sex'])
X_test['Sex'] = X_test.Sex.cat.codes

# %% [markdown]
# # Model setup

# %%
from tensorflow import keras
#from sklearn.model_selection import train_test_split

def get_compiled_model():
  model = keras.Sequential([
      keras.layers.Dense(128, activation='relu'),
      keras.layers.Dense(128, activation='relu'),
      keras.layers.Dense(1, activation='sigmoid')
  ])

  model.compile(optimizer='adam',
              loss='binary_crossentropy',
              metrics=['accuracy'])
  
  return model

# %% [markdown]
# Train model

# %%
model = get_compiled_model()
model.fit(X_train.values, y_train.values, epochs=10)
# Out:
# Train on 891 samples
# Epoch 1/10
# 891/891 [==============================] - 0s 224us/sample - loss: 0.5725 - acc: 0.7385
# Epoch 2/10
# 891/891 [==============================] - 0s 56us/sample - loss: 0.4845 - acc: 0.7722
# Epoch 3/10
# 891/891 [==============================] - 0s 59us/sample - loss: 0.4459 - acc: 0.8103
# Epoch 4/10
# 891/891 [==============================] - 0s 57us/sample - loss: 0.4253 - acc: 0.8159
# Epoch 5/10
# 891/891 [==============================] - 0s 59us/sample - loss: 0.4163 - acc: 0.8249
# Epoch 6/10
# 891/891 [==============================] - 0s 59us/sample - loss: 0.4113 - acc: 0.8215
# Epoch 7/10
# 891/891 [==============================] - 0s 59us/sample - loss: 0.4044 - acc: 0.8328
# Epoch 8/10
# 891/891 [==============================] - 0s 60us/sample - loss: 0.4030 - acc: 0.8238
# Epoch 9/10
# 891/891 [==============================] - 0s 64us/sample - loss: 0.3991 - acc: 0.8350
# Epoch 10/10
# 891/891 [==============================] - 0s 65us/sample - loss: 0.3976 - acc: 0.8373

# %% [markdown]
# # Predict

# %%
predictions = model.predict(X_test.values)

# %%
def save_to_csv(filename, str):
  with open(filename, 'a') as csv:
    csv.write(str + "\n")

# %%
for prediction, PassengerId in zip(predictions, X_test.index):
  if np.isnan(prediction[0]):
    prediction[0] = 0
  str = '{},{}'.format(PassengerId, int(round(prediction[0])))
  #print(str)
  save_to_csv('predictions.csv', str)
# Out:
# 892,0
# 893,0
# 894,0
# 895,0
# 896,0
# 897,0
# 898,1
# 899,0
# 900,1
# 901,0
# 902,0
# 903,0
# 904,1
# 905,0
# 906,1
# 907,1
# 908,0
# 909,0
# 910,0
# 911,0
# 912,1
# 913,1
# 914,1
# 915,1
# 916,1
# 917,0
# 918,1
# 919,0
# 920,0
# 921,0
# 922,0
# 923,0
# 924,0
# 925,0
# 926,1
# 927,0
# 928,1
# 929,1
# 930,0
# 931,0
# 932,0
# 933,1
# 934,0
# 935,1
# 936,1
# 937,0
# 938,0
# 939,0
# 940,1
# 941,0
# 942,1
# 943,0
# 944,1
# 945,1
# 946,0
# 947,0
# 948,0
# 949,0
# 950,0
# 951,1
# 952,0
# 953,0
# 954,0
# 955,1
# 956,1
# 957,1
# 958,1
# 959,0
# 960,1
# 961,1
# 962,1
# 963,0
# 964,1
# 965,1
# 966,1
# 967,0
# 968,0
# 969,1
# 970,0
# 971,1
# 972,1
# 973,1
# 974,0
# 975,0
# 976,0
# 977,0
# 978,1
# 979,1
# 980,1
# 981,1
# 982,0
# 983,0
# 984,1
# 985,0
# 986,1
# 987,0
# 988,1
# 989,0
# 990,1
# 991,0
# 992,1
# 993,0
# 994,0
# 995,0
# 996,1
# 997,0
# 998,0
# 999,0
# 1000,0
# 1001,0
# 1002,0
# 1003,1
# 1004,1
# 1005,1
# 1006,1
# 1007,0
# 1008,0
# 1009,1
# 1010,0
# 1011,1
# 1012,1
# 1013,0
# 1014,1
# 1015,0
# 1016,0
# 1017,1
# 1018,0
# 1019,0
# 1020,0
# 1021,0
# 1022,0
# 1023,0
# 1024,1
# 1025,0
# 1026,0
# 1027,0
# 1028,0
# 1029,0
# 1030,1
# 1031,0
# 1032,0
# 1033,1
# 1034,0
# 1035,0
# 1036,0
# 1037,0
# 1038,0
# 1039,0
# 1040,1
# 1041,0
# 1042,1
# 1043,0
# 1044,0
# 1045,0
# 1046,0
# 1047,0
# 1048,1
# 1049,1
# 1050,0
# 1051,1
# 1052,1
# 1053,1
# 1054,1
# 1055,0
# 1056,0
# 1057,0
# 1058,0
# 1059,0
# 1060,1
# 1061,1
# 1062,0
# 1063,0
# 1064,0
# 1065,0
# 1066,0
# 1067,1
# 1068,1
# 1069,1
# 1070,1
# 1071,1
# 1072,0
# 1073,1
# 1074,1
# 1075,0
# 1076,1
# 1077,0
# 1078,1
# 1079,0
# 1080,0
# 1081,0
# 1082,0
# 1083,1
# 1084,0
# 1085,0
# 1086,1
# 1087,0
# 1088,1
# 1089,1
# 1090,0
# 1091,1
# 1092,1
# 1093,1
# 1094,1
# 1095,1
# 1096,0
# 1097,1
# 1098,1
# 1099,0
# 1100,1
# 1101,0
# 1102,0
# 1103,0
# 1104,0
# 1105,1
# 1106,0
# 1107,0
# 1108,1
# 1109,1
# 1110,1
# 1111,0
# 1112,1
# 1113,0
# 1114,1
# 1115,0
# 1116,1
# 1117,1
# 1118,0
# 1119,1
# 1120,0
# 1121,0
# 1122,0
# 1123,1
# 1124,0
# 1125,0
# 1126,1
# 1127,0
# 1128,1
# 1129,0
# 1130,1
# 1131,1
# 1132,1
# 1133,1
# 1134,1
# 1135,0
# 1136,0
# 1137,1
# 1138,1
# 1139,0
# 1140,1
# 1141,1
# 1142,1
# 1143,0
# 1144,0
# 1145,0
# 1146,0
# 1147,0
# 1148,0
# 1149,0
# 1150,1
# 1151,0
# 1152,0
# 1153,0
# 1154,1
# 1155,1
# 1156,0
# 1157,0
# 1158,1
# 1159,0
# 1160,1
# 1161,0
# 1162,0
# 1163,0
# 1164,1
# 1165,1
# 1166,0
# 1167,1
# 1168,0
# 1169,0
# 1170,0
# 1171,0
# 1172,1
# 1173,1
# 1174,1
# 1175,1
# 1176,1
# 1177,0
# 1178,0
# 1179,1
# 1180,0
# 1181,0
# 1182,1
# 1183,1
# 1184,0
# 1185,1
# 1186,0
# 1187,0
# 1188,1
# 1189,0
# 1190,1
# 1191,0
# 1192,0
# 1193,0
# 1194,0
# 1195,0
# 1196,1
# 1197,1
# 1198,1
# 1199,1
# 1200,1
# 1201,0
# 1202,0
# 1203,0
# 1204,0
# 1205,1
# 1206,1
# 1207,1
# 1208,1
# 1209,0
# 1210,0
# 1211,0
# 1212,0
# 1213,0
# 1214,0
# 1215,1
# 1216,1
# 1217,0
# 1218,1
# 1219,0
# 1220,0
# 1221,0
# 1222,1
# 1223,0
# 1224,0
# 1225,0
# 1226,0
# 1227,1
# 1228,0
# 1229,0
# 1230,0
# 1231,0
# 1232,0
# 1233,0
# 1234,0
# 1235,1
# 1236,0
# 1237,1
# 1238,0
# 1239,1
# 1240,0
# 1241,1
# 1242,1
# 1243,0
# 1244,0
# 1245,0
# 1246,1
# 1247,0
# 1248,1
# 1249,0
# 1250,0
# 1251,1
# 1252,0
# 1253,1
# 1254,1
# 1255,0
# 1256,1
# 1257,0
# 1258,0
# 1259,1
# 1260,1
# 1261,0
# 1262,0
# 1263,1
# 1264,0
# 1265,0
# 1266,1
# 1267,1
# 1268,0
# 1269,0
# 1270,0
# 1271,0
# 1272,0
# 1273,0
# 1274,1
# 1275,1
# 1276,0
# 1277,1
# 1278,0
# 1279,0
# 1280,0
# 1281,0
# 1282,0
# 1283,1
# 1284,1
# 1285,0
# 1286,0
# 1287,1
# 1288,0
# 1289,1
# 1290,0
# 1291,0
# 1292,1
# 1293,0
# 1294,1
# 1295,1
# 1296,1
# 1297,0
# 1298,0
# 1299,1
# 1300,1
# 1301,1
# 1302,1
# 1303,1
# 1304,1
# 1305,0
# 1306,1
# 1307,0
# 1308,0
# 1309,0
